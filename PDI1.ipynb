# %% [markdown]
# <a href="https://colab.research.google.com/github/AnthonyArce97/PDI/blob/master/PDI1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **Importar las librerias necsarias**

# %%
#Importar librerias necesarias

import numpy as np  # numpy Para la creacion de matriz porque es mucho mejor 
import matplotlib.pyplot as plt #Graficar
import cv2 # Libreria de Open CV para python

#Graficar imagenes estaticas en el notebook

# %% [markdown]
# Forma habitual de leer y mostrar una imagen

# %%
image = cv2.imread('/content/drive/My Drive/PDI/cc.jpg')
cv2.imshow("Image", image)
cv2.waitKey(0)

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/My Drive/PDI/cc.jpg' , cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

# %% [markdown]
# **IMPORTAR IMAGEN**

# %%
# !pwd  #Ruta en la que estoy 
# !ls  #sabes que carpetas o archivos hay

# %cd /content/drive/My Drive/PDI
# !pwd

from google.colab.patches import cv2_imshow
img = cv2.imread('cc.jpg',cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(300),int(300)))
cv2_imshow(img)
# Out:
# /content
# drive  sample_data
# /content/drive/My Drive/PDI
# /content/drive/My Drive/PDI
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FF31B3957B8>

# %% [markdown]
# **OPCION 2**

# %%
import os

path= '/content/drive/My Drive/PDI'

os.chdir(path)
# !pwd

from google.colab.patches import cv2_imshow
img = cv2.imread('cc.jpg',cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(600),int(600)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/PDI
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FF31AF734A8>

# %%
img_BGR = cv2.imread('/content/drive/My Drive/PDI/cc.jpg',cv2.IMREAD_COLOR)
img_BGR2 = cv2.imread('/content/drive/My Drive/PDI/ricardo.jpg',cv2.IMREAD_UNCHANGED)

plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # **DE BGR A RGB **

# %%
img_RGB = cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(7,7))
plt.imshow(img_RGB)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# **Convertir a escala de grices**

# %%
img_GRAY = cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(7,7))
plt.imshow(img_GRAY,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# **USAR METODO SPARA MPSTRAR LAS IMAGENES **

# %%
def display (a, b, title1='Original',title2='Edited'):
  plt.figure(figsize=(14,14))
  plt.subplot(121),plt.imshow(a),plt.title(title1)
  plt.xticks([]),plt.yticks([])
  plt.subplot(122),plt.imshow(b,cmap='gray'),plt.title(title2)
  plt.xticks([]),plt.yticks([])
  plt.show()

def  display_one(a,title1='Original'):
  plt.imshow(a) , plt.title(title1)
  plt.show()


display_one(img_BGR)





display(img_BGR,img_GRAY,'Original','Gray')

# %%
def display (a,b,c,d, title1='Original',title2='Edited',title3='Edited',title4='Edited'):
  plt.figure(figsize=(14,14))
  plt.subplot(221),plt.imshow(a),plt.title(title1)
  plt.xticks([]),plt.yticks([])
  plt.subplot(222),plt.imshow(b),plt.title(title2)
  plt.xticks([]),plt.yticks([])
  plt.subplot(223),plt.imshow(c),plt.title(title3)
  plt.xticks([]),plt.yticks([])
  plt.subplot(224),plt.imshow(d,cmap='gray'),plt.title(title4)
  plt.xticks([]),plt.yticks([])
  plt.show()

display(img_RGB,img_BGR,img_GRAY,img_GRAY,'Orginal','BGR','GRAY','GRAY')

# %%
def estadisticas(imagen):
  img_size=imagen.shape

  if len (img_size)>2:
    print("image chanels", img_size[2])
  else:
    print("image chanels", 1)

  print("image W", img_size[1])
  print("image H", img_size[2])
  print("min value", imagen.min())
  print("max value", imagen.max())
  print("prom", imagen.mean())
  print("type", imagen.dtype)

estadisticas(img_BGR)
# Out:
# image chanels 3
# image W 1200
# image H 3
# min value 0
# max value 255
# prom 57.26594296076492
# type uint8

# %%
images=[]
IMAGE_DIRECTORY='/content/drive/My Drive/PDI/'

def get_image(image_path):
  image = cv2.imread(image_path)
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  return image

for file in os.listdir(IMAGE_DIRECTORY):
  if not file.startswith('.'):
    images.append(get_image(os.path.join(IMAGE_DIRECTORY,file)))

plt.figure(figsize=(20,10))
for i in range(len(images)):
  plt.subplot(1,len(images),i+1)
  plt.imshow(images[i])

# %% [markdown]
# **[Cambiar tamaño imagen ](https://)**

# %%
print(img.shape)
res= cv2.resize(img,None,fx=10,fy=10,interpolation = cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (600, 600, 3)
# (6000, 6000, 3)
